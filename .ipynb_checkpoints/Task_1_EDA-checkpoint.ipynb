# %%
from pathlib import Path
import re

import pandas as pd

# %% [markdown]
# https://data.mos.ru/opendata?categoryId=121

# %%
DATA_PATH = Path('./data')

# %%
file_paths =  {
    'biblio': DATA_PATH/'data-102277-2020-04-02.csv',
    'cinema': DATA_PATH/'data-102278-2020-04-02.csv',
    'culture': DATA_PATH/'data-102279-2020-04-02.csv',
    'park':  DATA_PATH/'data-4214-2020-04-02.csv'
}

file_paths
# Out:
# {'biblio': PosixPath('data/data-102277-2020-04-02.csv'),
#  'cinema': PosixPath('data/data-102278-2020-04-02.csv'),
#  'culture': PosixPath('data/data-102279-2020-04-02.csv'),
#  'park': PosixPath('data/data-4214-2020-04-02.csv')}

# %% [markdown]
# **EDA**

# %%
pd.read_csv(file_paths['park'], encoding='windows-1251', sep=';')
# Out:
#         ID   global_id                 Name  \
# 0      337    46808732   Точка доступа №337
# 1      338    46808734   Точка доступа №338
# 2      339    46808736   Точка доступа №339
# 3      340    46808738   Точка доступа №340
# 4      341    46808740   Точка доступа №341
# ...    ...         ...                  ...
# 1230  1230  1033023963  Точка доступа №1230
# 1231  1231  1033023964  Точка доступа №1231
# 1232  1232  1033023965  Точка доступа №1232
# 1233  1233  1033023966  Точка доступа №1233
# 1234  1234  1033023967  Точка доступа №1234
#
#                                    AdmArea           District  \
# 0     Юго-Восточный административный округ    район Кузьминки
# 1     Юго-Восточный административный округ    район Кузьминки
# 2     Юго-Восточный административный округ    район Кузьминки
# 3     Юго-Восточный административный округ    район Кузьминки
# 4     Юго-Восточный административный округ    район Кузьминки
# ...                                    ...                ...
# 1230       Северный административный округ  Хорошёвский район
# 1231       Северный административный округ  Хорошёвский район
# 1232       Северный административный округ  Хорошёвский район
# 1233       Северный административный округ  Хорошёвский район
# 1234       Северный административный округ  Хорошёвский район
#
#                                                ParkName          WiFiName  \
# 0     Государственное автономное учреждение культуры...  Moscow_WiFi_Free
# 1     Государственное автономное учреждение культуры...  Moscow_WiFi_Free
# 2     Государственное автономное учреждение культуры...  Moscow_WiFi_Free
# 3     Государственное автономное учреждение культуры...  Moscow_WiFi_Free
# 4     Государственное автономное учреждение культуры...  Moscow_WiFi_Free
# ...                                                 ...               ...
# 1230  Государственное автономное учреждение культуры...  Moscow_WiFi_Free
# 1231  Государственное автономное учреждение культуры...  Moscow_WiFi_Free
# 1232  Государственное автономное учреждение культуры...  Moscow_WiFi_Free
# 1233  Государственное автономное учреждение культуры...  Moscow_WiFi_Free
# 1234  Государственное автономное учреждение культуры...  Moscow_WiFi_Free
#
#      CoverageArea FunctionFlag     AccessFlag Password Longitude_WGS84  \
# 0              20    действует  открытая сеть      NaN       37.769489
# 1              20    действует  открытая сеть      NaN       37.768175
# 2              20    действует  открытая сеть      NaN       37.768275
# 3              20    действует  открытая сеть      NaN       37.769618
# 4              20    действует  открытая сеть      NaN       37.769175
# ...           ...          ...            ...      ...             ...
# 1230           50    действует  открытая сеть      NaN       37.523119
# 1231           50    действует  открытая сеть      NaN       37.531689
# 1232           50    действует  открытая сеть      NaN       37.535538
# 1233           50    действует  открытая сеть      NaN       37.530539
# 1234           50    действует  открытая сеть      NaN       37.529938
#
#      Latitude_WGS84                                           geoData  \
# 0          55.69501   {type=Point, coordinates=[37.769489, 55.69501]}
# 1         55.695218  {type=Point, coordinates=[37.768175, 55.695218]}
# 2         55.695463  {type=Point, coordinates=[37.768275, 55.695463]}
# 3         55.695542  {type=Point, coordinates=[37.769618, 55.695542]}
# 4         55.695463  {type=Point, coordinates=[37.769175, 55.695463]}
# ...             ...                                               ...
# 1230      55.788378  {type=Point, coordinates=[37.523119, 55.788378]}
# 1231      55.787781  {type=Point, coordinates=[37.531689, 55.787781]}
# 1232      55.786484  {type=Point, coordinates=[37.535538, 55.786484]}
# 1233      55.785455  {type=Point, coordinates=[37.530539, 55.785455]}
# 1234      55.786578  {type=Point, coordinates=[37.529938, 55.786578]}
#
#       Unnamed: 14
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 1230          NaN
# 1231          NaN
# 1232          NaN
# 1233          NaN
# 1234          NaN
#
# [1235 rows x 15 columns]

# %%
dfs_list = []

for data_type, file_name in list(file_paths.items())[:1]:
    df = pd.read_csv(file_name, encoding='windows-1251', sep=';')
    print(data_type, len(df), df['Address'].head())
    df['source'] = data_type
    dfs_list.append(df)
    
full_df = pd.concat(dfs_list, axis=0, sort=False, ignore_index=True).reset_index(drop=True)
full_df.columns
# Out:
# biblio 372 0            город Москва, 11-я Парковая улица, дом 21
# 1    город Москва, 1-я Новокузьминская улица, дом 1...
# 2     город Москва, 2-й Красносельский переулок, дом 2
# 3        город Москва, 3-й Павловский переулок, дом 14
# 4        город Москва, 8-я улица Текстильщиков, дом 14
# Name: Address, dtype: object
# Index(['ID', 'LibraryName', 'AdmArea', 'District', 'Address',
#        'NumberOfAccessPoints', 'WiFiName', 'CoverageArea', 'FunctionFlag',
#        'AccessFlag', 'Password', 'Latitude_WGS84', 'Longitude_WGS84',
#        'global_id', 'geoData', 'Unnamed: 15', 'source'],
#       dtype='object')

# %%
full_df.describe(include='all')
# Out:
#                 ID                                        LibraryName  \
# count   372.000000                                                372
# unique         NaN                                                269
# top            NaN  Государственное бюджетное учреждение культуры ...
# freq           NaN                                                  4
# mean    186.500000                                                NaN
# std     107.531391                                                NaN
# min       1.000000                                                NaN
# 25%      93.750000                                                NaN
# 50%     186.500000                                                NaN
# 75%     279.250000                                                NaN
# max     372.000000                                                NaN
#
#                                    AdmArea           District  \
# count                                  372                372
# unique                                  11                123
# top     Центральный административный округ  Пресненский район
# freq                                    55                 10
# mean                                   NaN                NaN
# std                                    NaN                NaN
# min                                    NaN                NaN
# 25%                                    NaN                NaN
# 50%                                    NaN                NaN
# 75%                                    NaN                NaN
# max                                    NaN                NaN
#
#                                                   Address  \
# count                                                 372
# unique                                                369
# top     город Москва, Ружейный переулок, дом 4, строен...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         NumberOfAccessPoints          WiFiName  CoverageArea FunctionFlag  \
# count             372.000000               372         372.0          372
# unique                   NaN                 1           NaN            1
# top                      NaN  Moscow_WiFi_Free           NaN    действует
# freq                     NaN               372           NaN          372
# mean                6.583333               NaN          50.0          NaN
# std                 3.468152               NaN           0.0          NaN
# min                 1.000000               NaN          50.0          NaN
# 25%                 4.000000               NaN          50.0          NaN
# 50%                 6.000000               NaN          50.0          NaN
# 75%                 8.000000               NaN          50.0          NaN
# max                28.000000               NaN          50.0          NaN
#
#            AccessFlag  Password  Latitude_WGS84  Longitude_WGS84  \
# count             372       0.0      372.000000       372.000000
# unique              1       NaN             NaN              NaN
# top     открытая сеть       NaN             NaN              NaN
# freq              372       NaN             NaN              NaN
# mean              NaN       NaN       55.738047        37.603705
# std               NaN       NaN        0.091397         0.142468
# min               NaN       NaN       55.500580        37.160075
# 25%               NaN       NaN       55.675193        37.516502
# 50%               NaN       NaN       55.744439        37.601735
# 75%               NaN       NaN       55.795766        37.709012
# max               NaN       NaN       56.007936        37.920727
#
#            global_id                                           geoData  \
# count   3.720000e+02                                               372
# unique           NaN                                               372
# top              NaN  {type=Point, coordinates=[37.867259, 55.817097]}
# freq             NaN                                                 1
# mean    9.145633e+08                                               NaN
# std     4.713181e+07                                               NaN
# min     8.789548e+08                                               NaN
# 25%     8.800361e+08                                               NaN
# 50%     8.948117e+08                                               NaN
# 75%     9.085660e+08                                               NaN
# max     1.026679e+09                                               NaN
#
#         Unnamed: 15  source
# count           0.0     372
# unique          NaN       1
# top             NaN  biblio
# freq            NaN     372
# mean            NaN     NaN
# std             NaN     NaN
# min             NaN     NaN
# 25%             NaN     NaN
# 50%             NaN     NaN
# 75%             NaN     NaN
# max             NaN     NaN

# %%
building_pat = re.compile(r'(дом\s+|корпус\s+|строение\s+|владение\s+)')

def not_building(s):
    return not re.search(building_pat, s)

# %%
full_df['clean_addr'] = full_df['Address'].str.split(',').apply(lambda x: list(filter(not_building, x))[-1].lower().strip())
full_df['clean_addr'].head()
# Out:
# 0            11-я парковая улица
# 1      1-я новокузьминская улица
# 2    2-й красносельский переулок
# 3        3-й павловский переулок
# 4        8-я улица текстильщиков
# Name: clean_addr, dtype: object

# %%
print(full_df['clean_addr'].unique().tolist())
# Out:
# ['11-я парковая улица', '1-я новокузьминская улица', '2-й красносельский переулок', '3-й павловский переулок', '8-я улица текстильщиков', '9-я улица соколиной горы', 'аминьевское шоссе', 'аптекарский переулок', 'аргуновская улица', 'артековская улица', 'банный переулок', 'бауманская улица', 'большая грузинская улица', 'большая дорогомиловская улица', 'большая переяславская улица', 'большая татарская улица', 'большая черкизовская улица', 'большой факельный переулок', 'верхоянская улица', 'волочаевская улица', 'глазовский переулок', 'даниловская набережная', 'дмитровское шоссе', 'дорожная улица', 'дубининская улица', 'зарайская улица', 'звёздный бульвар', 'кастанаевская улица', 'каширское шоссе', 'коломенская улица', 'коломенский проезд', 'коптевская улица', 'краснодарская улица', 'кременчугская улица', 'кутузовский проспект', 'ленинский проспект', 'лялин переулок', 'микрорайон северное чертаново', 'михалковская улица', 'мичуринский проспект', 'нежинская улица', 'нижегородская улица', 'новодевичий проезд', 'новозаводская улица', 'октябрьская улица', 'онежская улица', 'ореховый бульвар', 'парусный проезд', 'проспект мира', 'профсоюзная улица', 'ростовская набережная', 'рязанский проспект', 'садовая-кудринская улица', 'саратовская улица', 'севанская улица
# 359    город Москва, город Зеленоград, корпус 607А
# Name: Address, dtype: object

# %%
full_df.groupby('Address')['NumberOfAccessPoints'].sum().sort_values(ascending=False)
# Out:
# Address
# город Москва, город Зеленоград, корпус 607А                                       31
# город Москва, бульвар Яна Райниса, дом 1                                          28
# город Москва, город Зеленоград, корпус 1004                                       22
# город Москва, улица Конёнкова, дом 23                                             21
# город Москва, Сущёвская улица, дом 14                                             21
#                                                                                   ..
# город Москва, Боровский проезд, дом 6                                              1
# город Москва, Большая Филёвская улица, дом 19/18, корпус 1                         1
# город Москва, Волгоградский проспект, дом 91                                       1
# город Москва, Рождественская улица, дом 12                                         1
# город Москва, поселение Внуковское, посёлок Минвнешторга, улица Ленина, дом 23     1
# Name: NumberOfAccessPoints, Length: 369, dtype: int64

# %%
full_stats_df = full_df.groupby('clean_addr')['NumberOfAccessPoints'].sum().sort_values(ascending=False)
full_stats_df
# Out:
# clean_addr
# город зеленоград           93
# бульвар яна райниса        28
# дмитровское шоссе          28
# улица конёнкова            21
# сущёвская улица            21
#                            ..
# улица короленко             1
# улица ленина                1
# боровский проезд            1
# рождественская улица        1
# большая филёвская улица     1
# Name: NumberOfAccessPoints, Length: 319, dtype: int64

# %%
full_df['clean_addr'].str.len().value_counts()
# Out:
# 15    73
# 17    70
# 18    70
# 16    64
# 19    45
# 22    41
# 14    41
# 13    36
# 20    32
# 23    29
# 21    26
# 24    21
# 26    13
# 25     9
# 29     7
# 27     4
# 12     3
# 11     3
# 32     1
# 28     1
# 10     1
# Name: clean_addr, dtype: int64

# %%
park_wifi_df = pd.read_csv(file_paths['park'], encoding='windows-1251', sep=';', skiprows=[1001])
park_wifi_df.head()
# Out:
#     ID  global_id                Name                               AdmArea  \
# 0  337   46808732  Точка доступа №337  Юго-Восточный административный округ
# 1  338   46808734  Точка доступа №338  Юго-Восточный административный округ
# 2  339   46808736  Точка доступа №339  Юго-Восточный административный округ
# 3  340   46808738  Точка доступа №340  Юго-Восточный административный округ
# 4  341   46808740  Точка доступа №341  Юго-Восточный административный округ
#
#           District                                           ParkName  \
# 0  район Кузьминки  Государственное автономное учреждение культуры...
# 1  район Кузьминки  Государственное автономное учреждение культуры...
# 2  район Кузьминки  Государственное автономное учреждение культуры...
# 3  район Кузьминки  Государственное автономное учреждение культуры...
# 4  район Кузьминки  Государственное автономное учреждение культуры...
#
#            WiFiName  CoverageArea FunctionFlag     AccessFlag  Password  \
# 0  Moscow_WiFi_Free            20    действует  открытая сеть       NaN
# 1  Moscow_WiFi_Free            20    действует  открытая сеть       NaN
# 2  Moscow_WiFi_Free            20    действует  открытая сеть       NaN
# 3  Moscow_WiFi_Free            20    действует  открытая сеть       NaN
# 4  Moscow_WiFi_Free            20    действует  открытая сеть       NaN
#
#    Longitude_WGS84  Latitude_WGS84  \
# 0        37.769489       55.695010
# 1        37.768175       55.695218
# 2        37.768275       55.695463
# 3        37.769618       55.695542
# 4        37.769175       55.695463
#
#                                             geoData  Unnamed: 14
# 0   {type=Point, coordinates=[37.769489, 55.69501]}          NaN
# 1  {type=Point, coordinates=[37.768175, 55.695218]}          NaN
# 2  {type=Point, coordinates=[37.768275, 55.695463]}          NaN
# 3  {type=Point, coordinates=[37.769618, 55.695542]}          NaN
# 4  {type=Point, coordinates=[37.769175, 55.695463]}          NaN

# %%
park_wifi_df.describe(include='all')
# Out:
#                  ID     global_id                Name  \
# count   1234.000000  1.234000e+03                1234
# unique          NaN           NaN                1234
# top             NaN           NaN  Точка доступа №207
# freq            NaN           NaN                   1
# mean     617.500000  2.151351e+08                 NaN
# std      356.369424  2.342120e+08                 NaN
# min        1.000000  4.680873e+07                 NaN
# 25%      309.250000  4.681368e+07                 NaN
# 50%      617.500000  1.692401e+08                 NaN
# 75%      925.750000  2.822880e+08                 NaN
# max     1234.000000  1.033024e+09                 NaN
#
#                                  AdmArea          District  \
# count                               1234              1234
# unique                                10                40
# top     Восточный административный округ  район Сокольники
# freq                                 364               165
# mean                                 NaN               NaN
# std                                  NaN               NaN
# min                                  NaN               NaN
# 25%                                  NaN               NaN
# 50%                                  NaN               NaN
# 75%                                  NaN               NaN
# max                                  NaN               NaN
#
#                                                  ParkName          WiFiName  \
# count                                                1234              1234
# unique                                                 42                 1
# top     Государственное автономное учреждение культуры...  Moscow_WiFi_Free
# freq                                                  165              1234
# mean                                                  NaN               NaN
# std                                                   NaN               NaN
# min                                                   NaN               NaN
# 25%                                                   NaN               NaN
# 50%                                                   NaN               NaN
# 75%                                                   NaN               NaN
# max                                                   NaN               NaN
#
#         CoverageArea FunctionFlag     AccessFlag  Password  Longitude_WGS84  \
# count    1234.000000         1234           1234       0.0      1234.000000
# unique           NaN            1              1       NaN              NaN
# top              NaN    действует  открытая сеть       NaN              NaN
# freq             NaN         1234           1234       NaN              NaN
# mean       25.713128          NaN            NaN       NaN        37.622388
# std        11.784165          NaN            NaN       NaN         0.106692
# min        20.000000          NaN            NaN       NaN        37.214444
# 25%        20.000000          NaN            NaN       NaN        37.547858
# 50%        20.000000          NaN            NaN       NaN        37.655222
# 75%        20.000000          NaN            NaN       NaN        37.678499
# max        50.000000          NaN            NaN       NaN        37.811684
#
#         Latitude_WGS84                                           geoData  \
# count      1234.000000                                              1234
# unique             NaN                                              1225
# top                NaN  {type=Point, coordinates=[37.681368, 55.615645]}
# freq               NaN                                                 2
# mean         55.765254                                               NaN
# std           0.071561                                               NaN
# min          55.615244                                               NaN
# 25%          55.729455                                               NaN
# 50%          55.762850                                               NaN
# 75%          55.795707                                               NaN
# max          55.990556                                               NaN
#
#         Unnamed: 14
# count           0.0
# unique          NaN
# top             NaN
# freq            NaN
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %%
park_wifi_df[park_wifi_df['FunctionFlag'] != 'действует']
# Out:
# Empty DataFrame
# Columns: [ID, global_id, Name, AdmArea, District, ParkName, WiFiName, CoverageArea, FunctionFlag, AccessFlag, Password, Longitude_WGS84, Latitude_WGS84, geoData, Unnamed: 14]
# Index: []

# %%
print(park_wifi_df['ParkName'].unique().tolist())
# Out:
# ['Государственное автономное учреждение культуры города Москвы «Государственный историко-архитектурный и природно-ландшафтный музей-заповедник «Кузьминки-Люблино»,
московский государственный объединенный художественный историко-архитектурный и природно-ландшафтный музей-заповедник», усадьба «Люблино»',
#        '«Музейно-парковый комплекс «Северное Тушино», парк «Северное Тушино»',
#        '«Парк культуры и отдыха «Сокольники»',
#        '«Парк культуры и отдыха «Таганский»',
#        '«Парк культуры и отдыха Фили»', '«Поклонная гора»',
#        '«Перовский парк культуры и отдыха»',
#        '«Социально реабилитационный центр ветеранов войн и вооружонных сил», Екатерининский парк',
#        '«Центральный парк культуры и отдыха имени М.Горького», Парк искусств «Музеон»',
#        '«Молодежный центр «Сетуньский Стан»',
#        '«Центральный парк культуры и отдыха имени М.Горького» Воробьевская набережная',
#        '«Московский государственный объединенный художественный историко-архитектурный и природно-ландшафтный музей-заповедник», усадьба «Коломенское»',
#        '«Центр социокультурных программ «Интеграция»', nan,
#        '«Музейно-парковый комплекс «Северное Тушино», зона отдыха «Покровский берег»',
#        '«Государственный историко-архитектурный и природно-ландшафтный музей-заповедник «Кузьминки-Люблино», Озелененная территория между Шипиловский проездом и Каширским шоссе',
#        '«Лианозовский парк культуры и отдыха», Парк «Северные Дубки»',
#        '«Парк культуры и отдыха «Красная Пресня», зона отдыха «Красногвардейские пруды»',
#        '«Музейно-парковый комплекс «Северное Тушино», зона отдыха «Левобережье»',
#        '«Государственный историко-архитектурный, художественный и ландшафтный музей-заповедник «Царицыно»',
#        '«Государственный историко-архитектурный и природно-ландшафтный музей-заповедник «Кузьминки-Люблино», Парк «Садовники»',
#        '«Парк культуры и отдыха «Бабушкинский», Сквер по Олонецкому проезду',
#        '«Государственный историко-архитектурный и природно-ландшафтный музей-заповедник «Кузьминки-Люблино», Присоединенная территория парка «Кузьминки»',
#        '«Государственный историко-архитектурный и природно-ландшафтный музей-заповедник «Кузьминки-Люблино», Усадьба «Влахернское-Кузьминки»',
#        '«Государственный историко-архитектурный и природно-ландшафтный музей-заповедник «Кузьминки-Люблино», Природно-исторический парк «Кузьминки-Люблино»',
#        '«Парк культуры и отдыха «Таганский», Детский парк',
#        '«Усадьба Воронцово»',
#        '«Парк культуры и отдыха Фили», Парк Олимпийской деревни',
#        '«Лианозовский парк культуры и отдыха», Парк «Гончаровский»',
#        '«Лианозовский парк культуры и отдыха», Парк «Ангарские пруды»',
#        '«Музей-усадьба «Кусково»',
#        '«Московский государственный объединенный художественный историко-архитектурный и природно-ландшафтный музей-заповедник», усадьба «Измайлово»',
#        '«Вагоноремонт»', '«Парк культуры и отдыха «Ходынское поле»'],
#       dtype=object)

# %%
park_stats_df = park_wifi_df.groupby('clean_park_name')['ID'].count().sort_values(ascending=False)
park_stats_df.head()
# Out:
# clean_park_name
# «Парк культуры и отдыха «Сокольники»                                                                                                              165
# «Московский государственный объединенный художественный историко-архитектурный и природно-ландшафтный музей-заповедник», усадьба «Коломенское»    121
# «Измайловский Парк культуры и отдыха»                                                                                                             120
# «Московский государственный зоологический парк»                                                                                                    74
# «Центральный парк культуры и отдыха имени М.Горького», Парк искусств «Музеон»                                                                      51
# Name: ID, dtype: int64

# %%
pd.concat([park_stats_df, full_stats_df], axis=0).sort_values(ascending=False)
# Out:
# «Парк культуры и отдыха «Сокольники»                                                                                                              165
# город зеленоград                                                                                                                                  122
# «Московский государственный объединенный художественный историко-архитектурный и природно-ландшафтный музей-заповедник», усадьба «Коломенское»    121
# «Измайловский Парк культуры и отдыха»                                                                                                             120
# «Московский государственный зоологический парк»                                                                                                    74
#                                                                                                                                                  ...
# улица исаковского                                                                                                                                   1
# улица короленко                                                                                                                                     1
# 1-й сетуньский проезд                                                                                                                               1
# рождественская улица                                                                                                                                1
# большой казённый переулок                                                                                                                           1
# Length: 461, dtype: int64
